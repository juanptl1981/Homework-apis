# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
from pprint import pprint
import pandas as pd
import numpy as np
import requests
import time
import seaborn as sns

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination

for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    #print(lat_lng)
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(cities)
len(cities)
# Out:
# ['itoman', 'chuy', 'barentsburg', 'carnarvon', 'new norfolk', 'bluff', 'fortuna', 'banda aceh', 'punta arenas', 'yellowknife', 'oistins', 'macau', 'ponta delgada', 'padang', 'byron bay', 'ushuaia', 'halifax', 'sarahan', 'belushya guba', 'palana', 'bethel', 'nyurba', 'dwarka', 'port hedland', 'atuona', 'bodden town', 'buala', 'abu dhabi', 'zhezkazgan', 'kahului', 'busselton', 'norman wells', 'clyde river', 'borujerd', 'petropavlovsk-kamchatskiy', 'albany', 'rikitea', 'romanovka', 'omboue', 'flin flon', 'liaocheng', 'benguela', 'chokurdakh', 'kununurra', 'harper', 'saint george', 'tiksi', 'nanortalik', 'hobart', 'lompoc', 'vaitupu', 'taolanaro', 'kupang', 'la rioja', 'bredasdorp', 'hualmay', 'nikolskoye', 'saleaula', 'los llanos de aridane', 'skaudvile', 'saint-philippe', 'faro', 'yantzaza', 'dikson', 'sakakah', 'naze', 'strezhevoy', 'sao cristovao', 'higuey', 'maniitsoq', 'maningrida', 'okhotsk', 'humaita', 'kodiak', 'sola', 'kapaa', 'honiara', 'cape town', 'kavieng', 'coahuayana', 'sibolga', 'port lincoln', 'havelock', 'parsabad', 'mar del plata', 'yulara', 'manuk mangkaw', 'asau', 'kamenskoye', 'goshogawara', 'port alfred', 'meadow lake', 'butaritari', 'ancud', 'sao joao da barra', 'kizema', 'torbay', 'tucuma', 'cayenne', 'vao', 'saint-augustin', 'lagoa', 'tumen', 'goderich', 'sentyabrskiy', 'qaanaaq', 'mirabad', 'pailitas', 'mataura', 'ca mau', 'longyearbyen', 'imeni poliny osipenko', 'kruisfontein', 'touros', 'marsala', 'lorengau', 'amderma', 'thinadhoo', 'kargil', 'naliya', 'mana', 'esperance', 'constitucion', 'northam', 'tasiilaq', 'sao bento', 'fukue', 'poum', 'attawapiskat', 'barrow', 'vaini', 'east london', 'tessalit', 'kungurtug', 'hilo', 'olafsvik', 'osmanabad', 'hasaki', 'mutsu', 'saskylakh', 'redwater', 'illoqqortoormiut', 'tateyama', 'aginskoye', 'tyulyachi', 'hermanus', 'vestmannaeyjar', 'krutinka', 'merauke', 'zhigansk', 'ahipara', 'weihe', 'turukhansk', 'leningradskiy', 'arlit', 'alberton', 'avarua', 'chandur bazar', 'olinda', 'norfolk', 'sandwick', 'gimli', 'buqayq', 'plettenberg bay', 'mareeba', 'sosva', 'nova odesa', 'imbituba', 'kaitangata', 'teya', 'khatanga', 'murzzuschlag', 'kutum', 'louis trichardt', 'awjilah', 'pisco', 'provideniya', 'narsaq', 'bubaque', 'mahebourg', 'sinnamary', 'castro', 'port elizabeth', 'jamestown', 'port hardy', 'birao', 'victoria', 'puerto ayora', 'nizhneyansk', 'nambour', 'khanpur', 'smithers', 'burgeo', 'faanui', 'charters towers', 'miraflores', 'prince rupert', 'newala', 'ambilobe', 'lucknow', 'airai', 'katubao', 'cabo san lucas', 'sur', 'severo-kurilsk', 'ribeira grande', 'souillac', 'tamano', 'georgetown', 'cidreira', 'boldog', 'berlevag', 'bengkulu', 'banjar', 'krasnoselkup', 'husavik', 'cherskiy', 'yerbogachen', 'burica', 'puerto colombia', 'odessa', 'san lorenzo', 'thompson', 'baoshan', 'chumikan', 'tsihombe', 'ixtapa', 'maceio', 'camargo', 'halalo', 'bocaiuva', 'arraial do cabo', 'srednekolymsk', 'mys shmidta', 'klaksvik', 'hithadhoo', 'cumaribo', 'shu', 'nome', 'cockburn town', 'san quintin', 'westport', 'humberto de campos', 'mount gambier', 'iqaluit', 'hoi an', 'sovetsk', 'rayagada', 'sao lourenco do sul', 'doctor pedro p. pena', 'upernavik', 'wynyard', 'kayerkan', 'bereda', 'bambous virieux', 'filadelfia', 'salta', 'salvador', 'mbanza-ngungu', 'moron', 'roma', 'tuktoyaktuk', 'punta alta', 'santa fe', 'zile', 'sindou', 'santa cruz', 'taoudenni', 'pevek', 'stadtallendorf', 'mandalgovi', 'kamaishi', 'varca', 'japura', 'galiwinku', 'miyako', 'tuatapere', 'sofiysk', 'oak harbor', 'dudinka', 'naron', 'willowmore', 'asfi', 'gotsu', 'lebu', 'pochutla', 'yeniseysk', 'anadyr', 'khuzdar', 'bloomingdale', 'hambantota', 'korem', 'druzhba', 'akdepe', 'saldanha', 'nipawin', 'talnakh', 'warmbad', 'tangzhai', 'ponta do sol', 'agde', 'borgarnes', 'saquena', 'morondava', 'skarnes', 'santander', 'vardo', 'san patricio', 'santiago del estero', 'makakilo city', 'sorland', 'ilulissat', 'sembe', 'never', 'dunedin', 'urengoy', 'buchanan', 'qurayyat', 'hamilton', 'atasu', 'mayya', 'catuday',  ...
# 605

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key

# %%
# Create empty lists to append the API data into lists 
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

# Start the call counter 
record = 1

# Log file print statement
print(f"Beginning Data Retrieval")
print(f"------------------------")

#Loop through the cities in the city list 
for city in cities:  
    
    # Try statement to append calls where value is found 
    # Not all calls return data as OpenWeatherMap will not have have records in all the cities generated by CityPy module
    try: 
        response = requests.get(f"{url}&q={city}").json() 
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        max_temp.append(response["main"]["temp_max"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        city_record = response["name"]
        print(f"Processing Record {record} | {city_record}")
        print(f"{url}&q={city}")
        
        # Increase counter by one 
        record= record + 1
        
        # Wait a second in loop to not over exceed rate limit of API
        time.sleep(1.01)
        
    # If no record found "skip" to next call
    except:
        print("City not found. Skipping...")
    continue
# Out:
# Beginning Data Retrieval
# ------------------------
# Processing Record 1 | Itoman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=itoman
# Processing Record 2 | Chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=chuy
# City not found. Skipping...
# Processing Record 3 | Carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=carnarvon
# Processing Record 4 | New Norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=new norfolk
# Processing Record 5 | Bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=bluff
# Processing Record 6 | Fortuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=fortuna
# Processing Record 7 | Banda Aceh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=banda aceh
# Processing Record 8 | Punta Arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=punta arenas
# Processing Record 9 | Yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=yellowknife
# Processing Record 10 | Oistins
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=oistins
# Processing Record 11 | Macau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=macau
# Processing Record 12 | Ponta Delgada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=ponta delgada
# Processing Record 13 | Padang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=padang
# Processing Record 14 | Byron Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=byron bay
# Processing Record 15 | Ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=ushuaia
# Processing Record 16 | Halifax
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=halifax
# Processing Record 17 | Sarahan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=sarahan
# City not found. Skipping...
# Processing Record 18 | Palana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=palana
# Processing Record 19 | Bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=bethel
# Processing Record 20 | Nyurba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=nyurba
# Processing Record 21 | Dwarka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=dwarka
# Processing Record 22 | Port Hedland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=port hedland
# Processing Record 23 | Atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=atuona
# Processing Record 24 | Bodden Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=bodden town
# Processing Record 25 | Buala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=buala
# Processing Record 26 | Abu Dhabi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=abu dhabi
# Processing Record 27 | Zhezkazgan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=zhezkazgan
# Processing Record 28 | Kahului
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=kahului
# Processing Record 29 | Busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=busselton
# Processing Record 30 | Norman Wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=norman wells
# Processing Record 31 | Clyde River
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=clyde river
# Processing Record 32 | Borujerd
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=borujerd
# Processing Record 33 | Petropavlovsk-Kamchatskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=petropavlovsk-kamchatskiy
# Processing Record 34 | Albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=albany
# Processing Record 35 | Rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=rikitea
# Processing Record 36 | Romanovka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=romanovka
# Processing Record 37 | Omboue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=omboue
# Processing Record 38 | Flin Flon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=flin flon
# Processing Record 39 | Liaocheng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=liaocheng
# Processing Record 40 | Benguela
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=benguela
# Processing Record 41 | Chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=chokurdakh
# Processing Record 42 | Kununurra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=kununurra
# Processing Record 43 | Harper
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=harper
# Processing Record 44 | Saint George
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=saint george
# Processing Record 45 | Tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=tiksi
# Processing Record 46 | Nanortalik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=nanortalik
# Processing Record 47 | Hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=hobart
# Processing Record 48 | Lompoc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=lompoc
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 49 | Kupang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=kupang
# Processing Record 50 | La Rioja
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=la rioja
# Processing Record 51 | Bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=bredasdorp
# Processing Record 52 | Hualmay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=hualmay
# Processing Record 53 | Nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=nikolskoye
# City not found. Skipping...
# Processing Record 54 | Los Llanos de Aridane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=los llanos de aridane
# Processing Record 55 | Skaudvile
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=skaudvile
# Processing Record 56 | Saint-Philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=saint-philippe
# Processing Record 57 | Faro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=faro
# Processing Record 58 | Yantzaza
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=yantzaza
# Processing Record 59 | Dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=dikson
# City not found. Skipping...
# Processing Record 60 | Naze
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=naze
# Processing Record 61 | Strezhevoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=strezhevoy
# Processing Record 62 | Sao Cristovao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=sao cristovao
# City not found. Skipping...
# Processing Record 63 | Maniitsoq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=maniitsoq
# Processing Record 64 | Maningrida
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=maningrida
# Processing Record 65 | Okhotsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=okhotsk
# Processing Record 66 | Humaita
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=humaita
# Processing Record 67 | Kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=kodiak
# Processing Record 68 | Sola
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=sola
# Processing Record 69 | Kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=kapaa
# Processing Record 70 | Honiara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=honiara
# Processing Record 71 | Cape Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=cape town
# Processing Record 72 | Kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=kavieng
# Processing Record 73 | Coahuayana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=coahuayana
# Processing Record 74 | Sibolga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=sibolga
# Processing Record 75 | Port Lincoln
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=port lincoln
# Processing Record 76 | Havelock
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=havelock
# Processing Record 77 | Parsabad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=parsabad
# Processing Record 78 | Mar del Plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=mar del plata
# Processing Record 79 | Yulara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=yulara
# Processing Record 80 | Manuk Mangkaw
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=manuk mangkaw
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 81 | Goshogawara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=goshogawara
# Processing Record 82 | Port Alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=port alfred
# Processing Record 83 | Meadow Lake
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=meadow lake
# Processing Record 84 | Butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=butaritari
# Processing Record 85 | Ancud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=ancud
# Processing Record 86 | Sao Joao da Barra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=sao joao da barra
# Processing Record 87 | Kizema
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=kizema
# Processing Record 88 | Torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=torbay
# City not found. Skipping...
# Processing Record 89 | Cayenne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=cayenne
# Processing Record 90 | Vao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=vao
# Processing Record 91 | Saint-Augustin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=saint-augustin
# Processing Record 92 | Lagoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=lagoa
# Processing Record 93 | Tumen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=tumen
# Processing Record 94 | Goderich
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=goderich
# City not found. Skipping...
# Processing Record 95 | Qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=qaanaaq
# Processing Record 96 | Mirabad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=mirabad
# Processing Record 97 | Pailitas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=pailitas
# Processing Record 98 | Mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=mataura
# Processing Record 99 | Ca Mau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=ca mau
# Processing Record 100 | Longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=longyearbyen
# Processing Record 101 | Imeni Poliny Osipenko
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=imeni poliny osipenko
# Processing Record 102 | Kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=kruisfontein
# Processing Record 103 | Touros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=touros
# Processing Record 104 | Marsala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=marsala
# Processing Record 105 | Lorengau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=lorengau
# City not found. Skipping...
# Processing Record 106 | Thinadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=thinadhoo
# Processing Record 107 | Kargil
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=kargil
# Processing Record 108 | Naliya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=naliya
# Processing Record 109 | Mana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=mana
# Processing Record 110 | Esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=esperance
# Processing Record 111 | Constitucion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=constitucion
# Processing Record 112 | Northam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=northam
# Processing Record 113 | Tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=tasiilaq
# City not found. Skipping...
# Processing Record 114 | Fukue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=fukue
# Processing Record 115 | Poum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=poum
# City not found. Skipping...
# Processing Record 116 | Barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=barrow
# Processing Record 117 | Vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=vaini
# Processing Record 118 | East London
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=east london
# Processing Record 119 | Tessalit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=tessalit
# Processing Record 120 | Kungurtug
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=kungurtug
# Processing Record 121 | Hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=hilo
# City not found. Skipping...
# Processing Record 122 | Osmanabad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=osmanabad
# Processing Record 123 | Hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=hasaki
# Processing Record 124 | Mutsu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=mutsu
# Processing Record 125 | Saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=saskylakh
# Processing Record 126 | Redwater
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=redwater
# City not found. Skipping...
# Processing Record 127 | Tateyama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=tateyama
# Processing Record 128 | Aginskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=aginskoye
# Processing Record 129 | Tyulyachi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=tyulyachi
# Processing Record 130 | Hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=hermanus
# Processing Record 131 | Vestmannaeyjar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=vestmannaeyjar
# Processing Record 132 | Krutinka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=krutinka
# Processing Record 133 | Merauke
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=merauke
# Processing Record 134 | Zhigansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=zhigansk
# Processing Record 135 | Ahipara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=ahipara
# Processing Record 136 | Weihe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=weihe
# Processing Record 137 | Turukhansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=turukhansk
# Processing Record 138 | Leningradskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=leningradskiy
# Processing Record 139 | Arlit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=arlit
# Processing Record 140 | Alberton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=alberton
# Processing Record 141 | Avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=avarua
# Processing Record 142 | Chandur Bazar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=chandur bazar
# Processing Record 143 | Olinda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=olinda
# Processing Record 144 | Norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=norfolk
# Processing Record 145 | Sandwick
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=sandwick
# Processing Record 146 | Gimli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=gimli
# City not found. Skipping...
# Processing Record 147 | Plettenberg Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=plettenberg bay
# Processing Record 148 | Mareeba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=mareeba
# Processing Record 149 | Sosva
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=sosva
# Processing Record 150 | Nova Odesa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=nova odesa
# Processing Record 151 | Imbituba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=imbituba
# Processing Record 152 | Kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=kaitangata
# Processing Record 153 | Teya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=teya
# Processing Record 154 | Khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=khatanga
# Processing Record 155 | Murzzuschlag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=murzzuschlag
# Processing Record 156 | Kutum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=kutum
# Processing Record 157 | Louis Trichardt
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=louis trichardt
# Processing Record 158 | Awjilah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=awjilah
# Processing Record 159 | Pisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=pisco
# Processing Record 160 | Provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=provideniya
# Processing Record 161 | Narsaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=narsaq
# Processing Record 162 | Bubaque
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=bubaque
# Processing Record 163 | Mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=mahebourg
# Processing Record 164 | Sinnamary
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=sinnamary
# Processing Record 165 | Castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=castro
# Processing Record 166 | Port Elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=port elizabeth
# Processing Record 167 | Jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=jamestown
# Processing Record 168 | Port Hardy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=port hardy
# Processing Record 169 | Birao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=birao
# Processing Record 170 | Victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=victoria
# Processing Record 171 | Puerto Ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=puerto ayora
# City not found. Skipping...
# Processing Record 172 | Nambour
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=nambour
# Processing Record 173 | Khanpur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=khanpur
# Processing Record 174 | Smithers
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=smithers
# Processing Record 175 | Burgeo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=burgeo
# Processing Record 176 | Faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=faanui
# Processing Record 177 | Charters Towers
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=charters towers
# Processing Record 178 | Miraflores
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=miraflores
# Processing Record 179 | Prince Rupert
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=prince rupert
# Processing Record 180 | Newala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=newala
# Processing Record 181 | Ambilobe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=ambilobe
# Processing Record 182 | Lucknow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=lucknow
# Processing Record 183 | Airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=airai
# Processing Record 184 | Katubao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=katubao
# Processing Record 185 | Cabo San Lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=cabo san lucas
# Processing Record 186 | Sur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=sur
# Processing Record 187 | Severo-Kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=severo-kurilsk
# Processing Record 188 | Ribeira Grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=ribeira grande
# Processing Record 189 | Souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=souillac
# Processing Record 190 | Tamano
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=tamano
# Processing Record 191 | Georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=georgetown
# Processing Record 192 | Cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=cidreira
# Processing Record 193 | Boldog
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=boldog
# Processing Record 194 | Berlevag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=berlevag
# City not found. Skipping...
# Processing Record 195 | Banjar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=banjar
# City not found. Skipping...
# Processing Record 196 | Husavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=husavik
# Processing Record 197 | Cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=cherskiy
# Processing Record 198 | Yerbogachen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=yerbogachen
# City not found. Skipping...
# Processing Record 199 | Puerto Colombia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=puerto colombia
# Processing Record 200 | Odessa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=odessa
# Processing Record 201 | San Lorenzo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=san lorenzo
# Processing Record 202 | Thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=thompson
# Processing Record 203 | Baoshan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=baoshan
# Processing Record 204 | Chumikan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=chumikan
# City not found. Skipping...
# Processing Record 205 | Ixtapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=ixtapa
# Processing Record 206 | Maceio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=maceio
# Processing Record 207 | Camargo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=camargo
# City not found. Skipping...
# Processing Record 208 | Bocaiuva
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=bocaiuva
# Processing Record 209 | Arraial do Cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=arraial do cabo
# Processing Record 210 | Srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=srednekolymsk
# City not found. Skipping...
# Processing Record 211 | Klaksvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=klaksvik
# Processing Record 212 | Hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=hithadhoo
# City not found. Skipping...
# Processing Record 213 | Shu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=shu
# Processing Record 214 | Nome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=nome
# Processing Record 215 | Cockburn Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=cockburn town
# Processing Record 216 | San Quintin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=san quintin
# Processing Record 217 | Westport
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=westport
# Processing Record 218 | Humberto de Campos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=humberto de campos
# Processing Record 219 | Mount Gambier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=mount gambier
# Processing Record 220 | Iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=iqaluit
# Processing Record 221 | Hoi An
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=hoi an
# Processing Record 222 | Sovetsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=sovetsk
# Processing Record 223 | Rayagada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=rayagada
# Processing Record 224 | Sao Lourenco do Sul
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=sao lourenco do sul
# City not found. Skipping...
# Processing Record 225 | Upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=upernavik
# Processing Record 226 | Wynyard
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=wynyard
# Processing Record 227 | Kayerkan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=kayerkan
# Processing Record 228 | Bereda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=bereda
# Processing Record 229 | Bambous Virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=bambous virieux
# Processing Record 230 | Filadelfia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=filadelfia
# Processing Record 231 | Salta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=salta
# Processing Record 232 | Salvador
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=salvador
# Processing Record 233 | Mbanza-Ngungu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=mbanza-ngungu
# Processing Record 234 | Moron
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=moron
# Processing Record 235 | Rome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=roma
# Processing Record 236 | Tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=tuktoyaktuk
# Processing Record 237 | Punta Alta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=punta alta
# Processing Record 238 | Santa Fe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=santa fe
# Processing Record 239 | Zile
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=zile
# Processing Record 240 | Sindou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=sindou
# Processing Record 241 | Santa Cruz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=santa cruz
# Processing Record 242 | Taoudenni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=taoudenni
# Processing Record 243 | Pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=pevek
# Processing Record 244 | Stadtallendorf
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=stadtallendorf
# Processing Record 245 | Mandalgovi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=mandalgovi
# Processing Record 246 | Kamaishi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=kamaishi
# Processing Record 247 | Varca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=varca
# Processing Record 248 | Japura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a048b53f88405abc8d6de0881d759052&q=japura

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create a dictonary with the lists generated
weatherpy_dict = {
    "City": city_name,
    "Cloudiness":cloudiness, 
    "Country":country,
    "Date":date, 
    "Humidity": humidity,
    "Lat":lat, 
    "Lng":lng, 
    "Max Temp": max_temp,
    "Wind Speed":wind_speed
}

# Create a data frame from dictionary
weather_data = pd.DataFrame(weatherpy_dict)

# Display count of weather data values 
weather_data.count()
print(weather_data)

# %%
# Save data frame to CSV
weather_data.to_csv('Output_CSV/weather_data.csv')

# Display data frame head 
weather_data.head()

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature")
plt.ylabel("Max. Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Output_Plots/Max_Temp_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Humidity"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Output_Plots/Humidity_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Output_Plots/Cloudiness_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Output_Plots/Wind_Speed_vs_Latitude.png")

# Show plot
plt.show()
